# %%
#Optimized version by making two recursive calls and not separate recursive calls.

class BinaryTreeNode:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
    
def printTree(root):
    if root == None:
        return
    print(root.data)
    printTree(root.left)
    printTree(root.right)
    
def printTreeDetailed(root):
    if root == None:
        return
    print(root.data, end=": ")
    if root.left != None:
        print("L", root.left.data, end=',')
    if root.right != None:
        print("R", root.right.data, end='')
    print()
    printTreeDetailed(root.left)
    printTreeDetailed(root.right)

def treeInput():
    rootData = int(input())
    if rootData == -1:
        return None
    root = BinaryTreeNode(rootData)
    leftTree = treeInput()
    rightTree = treeInput()
    root.left = leftTree
    root.right = rightTree
    return root

def height(root):
    if root == None:
        return 0
    return 1 + max(height(root.left), height(root.right))

def getHeightandCheckBalanced(root):
    if root == None:
        return 0, True
    
    leftHeight , isLeftBalanced = getHeightandCheckBalanced(root.left)
    rightHeight , isRightBalanced = getHeightandCheckBalanced(root.right)
    
    height = 1 + max(leftHeight, rightHeight)
    if leftHeight - rightHeight > 1 or rightHeight - leftHeight > 1:
        return height,False
    
    if isLeftBalanced and isRightBalanced:
        return height, True
    else:
        return height, False

def isBalanced2(root):
    height, isRootBalanced = getHeightandCheckBalanced(root)
    return isRootBalanced

root = treeInput()
print("Tree Details:")
printTreeDetailed(root)
print("Print tree height and check whether tree is balanced:")
print(getHeightandCheckBalanced(root))
print("Print whether the tree is balanced")
print(isBalanced2(root))
# Out:
# 1
# 2
# 4
# 6
# -1
# -1
# -1
# -1
# 3
# -1
# 5
# -1
# -1
# Tree Details:
# 1: L 2,R 3
# 2: L 4,
# 4: L 6,
# 6:
# 3: R 5
# 5:
# Print tree height and check whether tree is balanced:
# (4, False)
# Print whether the tree is balanced
# False

# %%
"""Input1: (Giving balanced tree input)
1
2
4
-1
-1
-1
3
-1
-1

Output1:
Tree Details:
1: L 2,R 3
2: L 4,
4: 
3: 
Print tree height and check whether tree is balanced:
(3, True)
Print whether the tree is balanced
True

Input2: (Giving not balanced tree input)
1
2
4
6
-1
-1
-1
-1
3
-1
5
-1
-1

Output2:
Tree Details:
1: L 2,R 3
2: L 4,
4: L 6,
6: 
3: R 5
5: 
Print tree height and check whether tree is balanced:
(4, False)
Print whether the tree is balanced
False"""
